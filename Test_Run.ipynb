# %%
import numpy as np
from nconpp import TensorNetwork

# %%
tensorList = [
    (np.random.randn(60)+1j*np.random.randn(60)).reshape(3,4,5),
    (np.random.randn(3780)+1j*np.random.randn(3780)).reshape(5, 3, 6, 7, 6),
    (np.random.randn(14)+1j*np.random.randn(14)).reshape(7,2),
    (np.random.randn(8)+1j*np.random.randn(8)).reshape(8),
    (np.random.randn(72)+1j*np.random.randn(72)).reshape(8,9),
    (np.random.randn(81)+1j*np.random.randn(81)).reshape(9,9)
]

legsList = [
    [3, -2, 2],
    [2, 3, 1, 4, 1],
    [4, -1],
    [5],
    [5, -3],
    [6, 6]
]

# %%
tn = TensorNetwork(tensorList, legsList)

# %%
tn.num_tensors
# Out:
# 6

# %%
tn.contract()

# %%
tn.num_tensors
# Out:
# 3

# %%
tn.connect()

# %%
tn.num_tensors
# Out:
# 1

# %%
tn.vertices[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: Unregistered type : Graph<GRAPH_PROPERTIES::custom_vertex_properties<std::complex<double> >,GRAPH_PROPERTIES::custom_edge_properties>::vertex_properties
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tn.vertices[0]
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	(self: nconpp._nconpp.TensorNetwork) -> Dict[int, Graph<GRAPH_PROPERTIES::custom_vertex_properties<std::complex<double> >,GRAPH_PROPERTIES::custom_edge_properties>::vertex_properties]
#
# Did you forget to `#include <pybind11/stl.h>`? Or <pybind11/complex.h>,
# <pybind11/functional.h>, <pybind11/chrono.h>, etc. Some automatic
# conversions are optional and require extra headers to be included
# when compiling your pybind11 module.

# %%
import numpy as np
import nconpp as ncp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/mircomarahrens/Repositories/nconpp/Test_Run.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bfedora-35/home/mircomarahrens/Repositories/nconpp/Test_Run.ipynb#ch0000000vscode-remote?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell://wsl%2Bfedora-35/home/mircomarahrens/Repositories/nconpp/Test_Run.ipynb#ch0000000vscode-remote?line=1'>2</a> import nconpp as ncp
#
# File ~/Repositories/nconpp/nconpp-venv/lib64/python3.10/site-packages/nconpp/__init__.py:1, in <module>
# ----> <a href='file:///home/mircomarahrens/Repositories/nconpp/nconpp-venv/lib64/python3.10/site-packages/nconpp/__init__.py?line=0'>1</a> from ._nconpp import contract
#
# ModuleNotFoundError: No module named 'nconpp._nconpp'

# %%
containerList = [
    (np.random.randn(60)+1j*np.random.randn(60)).reshape(3,4,5),
    (np.random.randn(3780)+1j*np.random.randn(3780)).reshape(5, 3, 6, 7, 6),
    (np.random.randn(14)+1j*np.random.randn(14)).reshape(7,2),
    (np.random.randn(8)+1j*np.random.randn(8)).reshape(8),
    (np.random.randn(72)+1j*np.random.randn(72)).reshape(8,9),
    (np.random.randn(81)+1j*np.random.randn(81)).reshape(9,9)
]

legsList = [
    [3, -2, 2],
    [2, 3, 1, 4, 1],
    [4, -1],
    [5],
    [5, -3],
    [6, 6]
]

# %%
result = ncp.contract(containerList, legsList)

# %%
result.shape
# Out:
# (2, 4, 9)

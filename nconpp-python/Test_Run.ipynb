# %%
import numpy as np
import nconpp as ncp

a = np.arange(15, dtype=complex).reshape(3, 5)
ncp.contract([a,a], [[1,1],[1]])
# Out:
# array([[ 0.+0.j,  2.+0.j,  4.+0.j,  6.+0.j,  8.+0.j],
#        [10.+0.j, 12.+0.j, 14.+0.j, 16.+0.j, 18.+0.j],
#        [20.+0.j, 22.+0.j, 24.+0.j, 26.+0.j, 28.+0.j]])

# %%
containerList = [
    (np.random.random(60) + np.random.random(60)*1j).reshape(3,4,5),
    (np.random.random(3780) + np.random.random(3780)*1j).reshape(5, 3, 6, 7, 6),
    (np.random.random(14) + np.random.random(14)*1j).reshape(7,2),
    (np.random.random(8) + np.random.random(8)*1j).reshape(8),
    (np.random.random(72) + np.random.random(72)*1j).reshape(8,9),
    (np.random.random(81) + np.random.random(81)*1j).reshape(9,9)
]

legsList = [
    [3, -2, 2],
    [2, 3, 1, 4, 1],
    [4, -1],
    [5],
    [5, -3],
    [6, 6]
]

# %%
a = (np.random.random(9)+np.random.random(9)*1j).reshape(3,3)
type(a)

# %%
ncp.contract([a], [[1,1]])

# %%
ncp.contract(containerList, legsList)

# %%
import numpy as np
import nconpp as xt

from IPython.display import display

# %% [markdown]
# ### Function example1

# %%
print(xt.example1.__doc__)

# %%
a = np.arange(15).reshape(3, 5) + 5
b = xt.example1(a)
display(a)
display(b)

# %% [markdown]
# ### Function example2

# %%
print(xt.example2.__doc__)

# %%
a = np.arange(15).reshape(3, 5)
b = xt.example2(a)
display(a)
display(b)

# %% [markdown]
# ### Function readme_example1

# %%
print(xt.readme_example1.__doc__)

# %%
PI = np.pi
a = np.linspace(0, PI, 100)
b = xt.readme_example1(a)
display(a)
display(np.sin(a).sum())
display(b)

# %% [markdown]
# ### Function vectorize_example1

# %%
print(xt.vectorize_example1.__doc__)

# %%
PI = np.pi
a = np.linspace(0, PI, 10)
b = np.linspace(0, 2*PI, 10)
c = xt.vectorize_example1(a, b)
d = np.sin(a)+np.cos(b)
display(a)
display(b)
display(c)
display(np.isclose(c, d))
